# %%
import pandas
import numpy
import matplotlib.pyplot as plt
from matplotlib.ticker import FixedLocator

# %% [markdown]
# ###  for 2**20 size array

# %%
no=[1,2,4,8,16]
t=[0.0486912,0.026366,0.0162837,0.0128029,0.0113025]

# %%
plt.plot(no,t)
plt.title('Time for a fixed array of 2**20');
plt.xlabel('Threads')
plt.ylabel('Time in seconds')
plt.grid()

# %%
ll=[]
for i in range(len(t)):
    if i==0:
        ll.append(1)
    else:
        ll.append(t[0]/t[i])
plt.plot(no,ll)
plt.title('Speedup for a fixed array of 2**20');
plt.xlabel('Threads')
plt.ylabel('Speedup')
plt.grid()

# %%
cost=[]
for i in range(len(t)):
        cost.append(t[i]*no[i])
plt.plot(no,cost)
plt.title('Cost for a fixed array of 2**20');
plt.xlabel('Threads')
plt.ylabel('Cost')
plt.grid()

# %%
eff=[]
for i in range(len(t)):
        eff.append((t[0]/(t[i]*no[i]))*100)
plt.plot(no,eff)
plt.title('Efficiency for a fixed array of 2**20');
plt.xlabel('Threads')
plt.ylabel('Efficiency (%)')
plt.grid()

# %% [markdown]
# ###  for 2**16 size array

# %%
no=[1,2,4,8,16]
t=[0.00216052,0.00120028,0.0007802,0.00064012,0.00062012]

# %%
ll=[]
for i in range(len(t)):
    if i==0:
        ll.append(1)
    else:
        ll.append(t[0]/t[i])
plt.plot(no,ll)
plt.ylim((1,4))
plt.title('Speedup for a fixed array of 2**16'); # plt.scatter if needed
plt.grid()

# %%
cost=[]
for i in range(len(t)):
        cost.append(t[i]*no[i])
plt.plot(no,cost)
plt.title('Cost for a fixed array of 2**16');
plt.grid()

# %%
eff=[]
for i in range(len(t)):
        eff.append((t[0]/(t[i]*no[i]))*100)
plt.plot(no,eff)
plt.title('Efficiency for a fixed array of 2**16');
plt.xlabel('Threads')
plt.ylabel('Efficiency (%)')
plt.grid()

# %% [markdown]
# # Ignore this cell

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.matshow(np.random.random((50,50)));
plt.colorbar()
plt.show()

# %% [markdown]
# # Ignore this cell

# %%
from scipy.stats import multivariate_normal

X = [1,2,4,8,16]

Y = 

X, Y = np.meshgrid(X,Y)

X_mean = 0; Y_mean = 0

X_var = 5; Y_var = 8

pos = np.empty(X.shape+(2,))

pos[:,:,0]=X

pos[:,:,1]=Y

rv = multivariate_normal([X_mean, Y_mean],[[X_var, 0], [0, Y_var]])

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, rv.pdf(pos), cmap="plasma")

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

X = [1,2,4,8,16]
Y = [2**i for i in range(3,21)]
X,Y = np.meshgrid(X, Y)
Z=np.zeros((18,5))

Z[0,0]=0
Z[1,0]=0
Z[2,0]=0
Z[3,0]=0
Z[4,0]=0
Z[5,0]=0
Z[6,0]=0
Z[7,0]=4*10**(-5) #1024
Z[8,0]=4*10**(-5)
Z[9,0]=0.00010002
Z[10,0]=0.00022006
Z[11,0]=0.0004401
Z[12,0]=0.00098024
Z[13,0]=0.00216052
Z[14,0]=0.00470106
Z[15,0]=0.0102623
Z[16,0]=0.0223655
Z[17,0]=0.0486912

Z[0,1]=0
Z[1,1]=0
Z[2,1]=0
Z[3,1]=0
Z[4,1]=0
Z[5,1]=0
Z[6,1]=0
Z[7,1]=2*10**(-5) #1024
Z[8,1]=6*10**(-5) 
Z[9,1]=6*10**(-5)
Z[10,1]=0.00014004
Z[11,1]=0.00030008
Z[12,1]=0.00060012
Z[13,1]=0.00120028
Z[14,1]=0.0026006
Z[15,1]=0.00564132
Z[16,1]=0.0122628
Z[17,1]=0.026366

Z[0,2]=0
Z[1,2]=0
Z[2,2]=0
Z[3,2]=0
Z[4,2]=0
Z[5,2]=0
Z[6,2]=0
Z[7,2]=4*10**(-5)
Z[8,2]=4*10**(-5)
Z[9,2]=6*10**(-5)
Z[10,2]=0.00010002
Z[11,2]=0.00020004
Z[12,2]=0.00038012
Z[13,2]=0.0007802
Z[14,2]=0.00164036
Z[15,2]=0.00354084
Z[16,2]=0.00754174
Z[17,2]=0.0162837

Z[0,3]=0
Z[1,3]=0
Z[2,3]=0
Z[3,3]=0
Z[4,3]=0
Z[5,3]=0
Z[6,3]=0
Z[7,3]=4*10**(-5)
Z[8,3]=4*10**(-5)
Z[9,3]=4*10**(-5)
Z[10,3]=0.0001
Z[11,3]=0.00020008
Z[12,3]=0.00032004
Z[13,3]=0.00064012
Z[14,3]=0.00126028
Z[15,3]=0.0026406
Z[16,3]=0.00560128
Z[17,3]=0.0128029


Z[0,4]=0
Z[1,4]=0
Z[2,4]=0
Z[3,4]=0
Z[4,4]=0
Z[5,4]=0
Z[6,4]=0
Z[7,4]=2*10**(-5)
Z[8,4]=6*10**(-5)
Z[9,4]=8*10**(-5)
Z[10,4]=9.998e-005
Z[11,4]=0.00020006
Z[12,4]=0.00032006
Z[13,4]=0.00062012
Z[14,4]=0.00122028
Z[15,4]=0.00250056
Z[16,4]=0.0053012
Z[17,4]=0.0113025
# Out:
# [8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576]
# (18, 5) (18, 5)
# [[0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00]
#  [0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00]
#  [0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00]
#  [0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00]
#  [0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00]
#  [0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00]
#  [0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00]
#  [4.00000e-05 2.00000e-05 4.00000e-05 4.00000e-05 2.00000e-05]
#  [4.00000e-05 6.00000e-05 4.00000e-05 4.00000e-05 6.00000e-05]
#  [1.00020e-04 6.00000e-05 6.00000e-05 4.00000e-05 8.00000e-05]
#  [2.20060e-04 1.40040e-04 1.00020e-04 1.00000e-04 9.99800e-05]
#  [4.40100e-04 3.00080e-04 2.00040e-04 2.00080e-04 2.00060e-04]
#  [9.80240e-04 6.00120e-04 3.80120e-04 3.20040e-04 3.20060e-04]
#  [2.16052e-03 1.20028e-03 7.80200e-04 6.40120e-04 6.20120e-04]
#  [4.70106e-03 2.60060e-03 1.64036e-03 1.26028e-03 1.22028e-03]
#  [1.02623e-02 5.64132e-03 3.54084e-03 2.64060e-03 2.50056e-03]
#  [2.23655e-02 1.22628e-02 7.54174e-03 5.60128e-03 5.30120e-03]
#  [4.86912e-02 2.63660e-02 1.62837e-02 1.28029e-02 1.13025e-02]]

# %%
fig = plt.figure(figsize=(30,30))# creates space for a figure to be drawn 

# Uses a 3d prjection as model is supposed to be 3D
axes = fig.gca(projection ='3d')

# Plots the three dimensional data consisting of x, y and z 
axes.plot_surface(X, Y, Z) 
axes.set_xlabel('Threads')
axes.set_ylabel('Array size')
axes.set_zlabel('Time in seconds')
# show command is used to visualize data plot   
plt.show()
#plt.xlabel('Threads')
#lt.ylabel('Array size')
#plt.zlabel('Time in seconds')
# Out:
# c:\Users\omara\anaconda3\envs\venv\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   after removing the cwd from sys.path.
